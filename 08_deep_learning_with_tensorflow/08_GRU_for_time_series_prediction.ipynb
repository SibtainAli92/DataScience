# %% [markdown]
# # GRU for Time Series Prediction
#
# In this notebook, we will demonstrate how to use Gated Recurrent Units (GRU) neural networks for time series prediction.

# %%
# Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Note the change to GRU here
from sklearn.preprocessing import MinMaxScaler
# Out:
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Data Preparation
#
# First, let's load and visualize the Airline Passengers dataset.

# %%
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
dataframe = pd.read_csv(url, usecols=[1], engine='python')
plt.plot(dataframe)
plt.xlabel("Months")
plt.ylabel("Passengers")
plt.title("Monthly Total Airline Passengers 1949-1960")
plt.show()

# %% [markdown]
# ## Data Preprocessing
#
# Before training a GRU model, we need to preprocess our data. This involves scaling our data and converting it into the right shape

# %%
# Normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataframe.values.astype('float32'))

# Split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# ## Create Dataset Matrix
#
# This utility function creates a dataset matrix. Given data, and choosing a certain time step, it will create input-output pairs.

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Reshape into X=t and Y=t+1, choosing a timestep of 3
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# # GRU Model Building & Training

# %%
# Create and fit the GRU network
model = Sequential()
model.add(GRU(4, input_shape=(look_back, 1)))  # Change LSTM to GRU here
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)
# Out:
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 92/92 - 5s - loss: 0.0159 - 5s/epoch - 51ms/step
# Epoch 2/100
# 92/92 - 1s - loss: 0.0079 - 641ms/epoch - 7ms/step
# Epoch 3/100
# 92/92 - 1s - loss: 0.0059 - 649ms/epoch - 7ms/step
# Epoch 4/100
# 92/92 - 1s - loss: 0.0046 - 674ms/epoch - 7ms/step
# Epoch 5/100
# 92/92 - 1s - loss: 0.0039 - 725ms/epoch - 8ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0037 - 342ms/epoch - 4ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0032 - 303ms/epoch - 3ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0030 - 273ms/epoch - 3ms/step
# Epoch 9/100
# 92/92 - 1s - loss: 0.0031 - 506ms/epoch - 5ms/step
# Epoch 10/100
# 92/92 - 1s - loss: 0.0031 - 546ms/epoch - 6ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0030 - 443ms/epoch - 5ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0030 - 383ms/epoch - 4ms/step
# Epoch 13/100
# 92/92 - 1s - loss: 0.0028 - 741ms/epoch - 8ms/step
# Epoch 14/100
# 92/92 - 1s - loss: 0.0029 - 556ms/epoch - 6ms/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0028 - 406ms/epoch - 4ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0028 - 333ms/epoch - 4ms/step
# Epoch 17/100
# 92/92 - 1s - loss: 0.0027 - 695ms/epoch - 8ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0029 - 476ms/epoch - 5ms/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0027 - 390ms/epoch - 4ms/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0028 - 398ms/epoch - 4ms/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0026 - 339ms/epoch - 4ms/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0025 - 339ms/epoch - 4ms/step
# Epoch 23/100
# 92/92 - 1s - loss: 0.0026 - 515ms/epoch - 6ms/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0025 - 282ms/epoch - 3ms/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0024 - 270ms/epoch - 3ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0026 - 255ms/epoch - 3ms/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0024 - 275ms/epoch - 3ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0024 - 300ms/epoch - 3ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0024 - 261ms/epoch - 3ms/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0023 - 264ms/epoch - 3ms/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0023 - 265ms/epoch - 3ms/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0023 - 291ms/epoch - 3ms/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0023 - 287ms/epoch - 3ms/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0023 - 258ms/epoch - 3ms/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0022 - 323ms/epoch - 4ms/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0023 - 298ms/epoch - 3ms/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0022 - 316ms/epoch - 3ms/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0023 - 324ms/epoch - 4ms/step
# Epoch 39/100
# 92/92 - 1s - loss: 0.0022 - 647ms/epoch - 7ms/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0022 - 280ms/epoch - 3ms/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0022 - 306ms/epoch - 3ms/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0022 - 272ms/epoch - 3ms/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0023 - 262ms/epoch - 3ms/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0022 - 275ms/epoch - 3ms/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0021 - 288ms/epoch - 3ms/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0022 - 282ms/epoch - 3ms/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0022 - 261ms/epoch - 3ms/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0020 - 248ms/epoch - 3ms/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0021 - 382ms/epoch - 4ms/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0020 - 393ms/epoch - 4ms/step
# Epoch 51/100
# 92/92 - 1s - loss: 0.0021 - 630ms/epoch - 7ms/step
# Epoch 52/100
# 92/92 - 1s - loss: 0.0019 - 553ms/epoch - 6ms/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0023 - 436ms/epoch - 5ms/step
# Epoch 54/100
# 92/92 - 1s - loss: 0.0021 - 502ms/epoch - 5ms/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0020 - 435ms/epoch - 5ms/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0020 - 366ms/epoch - 4ms/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0020 - 372ms/epoch - 4ms/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0021 - 399ms/epoch - 4ms/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0021 - 407ms/epoch - 4ms/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0020 - 346ms/epoch - 4ms/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0019 - 381ms/epoch - 4ms/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0021 - 423ms/epoch - 5ms/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0020 - 432ms/epoch - 5ms/step
# Epoch 64/100
# 92/92 - 1s - loss: 0.0021 - 755ms/epoch - 8ms/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0020 - 359ms/epoch - 4ms/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0019 - 426ms/epoch - 5ms/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0021 - 256ms/epoch - 3ms/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0020 - 254ms/epoch - 3ms/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0020 - 284ms/epoch - 3ms/step
# Epoch 70/100
# 92/92 - 0s - loss: 0.0020 - 319ms/epoch - 3ms/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0021 - 291ms/epoch - 3ms/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0020 - 339ms/epoch - 4ms/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0020 - 389ms/epoch - 4ms/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0019 - 288ms/epoch - 3ms/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0019 - 331ms/epoch - 4ms/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0019 - 275ms/epoch - 3ms/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0019 - 271ms/epoch - 3ms/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0019 - 270ms/epoch - 3ms/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0019 - 270ms/epoch - 3ms/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0019 - 245ms/epoch - 3ms/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0019 - 253ms/epoch - 3ms/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0018 - 253ms/epoch - 3ms/step
# Epoch 83/100
# 92/92 - 1s - loss: 0.0018 - 601ms/epoch - 7ms/step
# Epoch 84/100
# 92/92 - 1s - loss: 0.0019 - 610ms/epoch - 7ms/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0019 - 363ms/epoch - 4ms/step
# Epoch 86/100
# 92/92 - 0s - loss: 0.0020 - 285ms/epoch - 3ms/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0019 - 281ms/epoch - 3ms/step
# Epoch 88/100
# 92/92 - 1s - loss: 0.0019 - 531ms/epoch - 6ms/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0019 - 275ms/epoch - 3ms/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0019 - 247ms/epoch - 3ms/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0019 - 243ms/epoch - 3ms/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0018 - 445ms/epoch - 5ms/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0020 - 300ms/epoch - 3ms/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0019 - 244ms/epoch - 3ms/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0019 - 256ms/epoch - 3ms/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0019 - 255ms/epoch - 3ms/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0018 - 251ms/epoch - 3ms/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0018 - 280ms/epoch - 3ms/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0018 - 342ms/epoch - 4ms/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0019 - 289ms/epoch - 3ms/step

# %% [markdown]
# # Model Evaluation

# %%
# Make predictions
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# Invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# Calculate root mean squared error
trainScore = np.sqrt(((trainPredict-y_train)**2).mean())
testScore = np.sqrt(((testPredict-y_test)**2).mean())
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 3/3 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# Train Score: 97.08 RMSE
# Test Score: 103.70 RMSE

# %% [markdown]
# # Visualizing Predictions

# %%
# Shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# Plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset), label="True data")
plt.plot(trainPredictPlot, label="Train Predictions")
plt.plot(testPredictPlot, label="Test Predictions")
plt.xlabel("Months")
plt.ylabel("Passengers")
plt.title("GRU's Prediction of Airline Passengers")
plt.legend()
plt.show()
