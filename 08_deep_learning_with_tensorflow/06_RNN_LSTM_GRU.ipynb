# %% [markdown]
# # RNN (Recurent Neural Network) - LSTM (Long Short Term Memory) - GRU (Gated Recurent Unit)

# %% [markdown]
# # RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential
# ignore warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Generate example data
X = np.random.rand(100, 10, 1)
y = np.random.randint(0, 2, size=(100,))

# %%
X.shape, y.shape
# Out:
# ((100, 10, 1), (100,))

# %%
# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:130: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Sibtain_Ali\.conda\envs\tensorflow\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 5s 58ms/step - loss: 0.7145 - accuracy: 0.4700
# Epoch 2/10
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6781 - accuracy: 0.5600
# Epoch 3/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6803 - accuracy: 0.5800
# Epoch 4/10
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6851 - accuracy: 0.5700
# Epoch 5/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6830 - accuracy: 0.5700
# Epoch 6/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6735 - accuracy: 0.6100
# Epoch 7/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6688 - accuracy: 0.5900
# Epoch 8/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6640 - accuracy: 0.5900
# Epoch 9/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6607 - accuracy: 0.5900
# Epoch 10/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6613 - accuracy: 0.5800
# 4/4 [==============================] - 1s 4ms/step - loss: 0.6595 - accuracy: 0.5900
# Test Loss: 0.6594643592834473
# Test Accuracy: 0.5899999737739563

# %% [markdown]
# # LSTM (Long Short Term Memory) is a special kind of RNN, capable of learning long-term dependencies.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))
df.head()
# Out:
#             value
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 6s 20ms/step - loss: 0.7033
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5611
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4362
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3359
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2538
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2029
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1745
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1750
# Epoch 9/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1727
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1704
# Epoch 11/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1672
# Epoch 12/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1645
# Epoch 13/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1606
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1591
# Epoch 15/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1576
# Epoch 16/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1560
# Epoch 17/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1545
# Epoch 18/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1532
# Epoch 19/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1515
# Epoch 20/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1500
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1483
# Epoch 22/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1462
# Epoch 23/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1448
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1428
# Epoch 25/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1408
# Epoch 26/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1385
# Epoch 27/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1364
# Epoch 28/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1350
# Epoch 29/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1327
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1311
# Epoch 31/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1311
# Epoch 32/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1275
# Epoch 33/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1233
# Epoch 34/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1217
# Epoch 35/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1241
# Epoch 36/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1178
# Epoch 37/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1184
# Epoch 38/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1165
# Epoch 39/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1135
# Epoch 40/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1058
# Epoch 41/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1078
# Epoch 42/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1127
# Epoch 43/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0976
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0973
# Epoch 45/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0934
# Epoch 46/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1072
# Epoch 47/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0891
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0958
# Epoch 49/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0949
# Epoch 50/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0832
# Epoch 51/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0816
# Epoch 52/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0830
# Epoch 53/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0741
# Epoch 54/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0896
# Epoch 55/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0812
# Epoch 56/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0742
# Epoch 57/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0737
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0708
# Epoch 59/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0706
# Epoch 60/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0703
# Epoch 61/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0693
# Epoch 62/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0679
# Epoch 63/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0674
# Epoch 64/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0660
# Epoch 65/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0655
# Epoch 66/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0660
# Epoch 67/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0654
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0661
# Epoch 69/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0633
# Epoch 70/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0637
# Epoch 71/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0616
# Epoch 72/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0610
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0608
# Epoch 74/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0605
# Epoch 75/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0608
# Epoch 76/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0611
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0594
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0648
# Epoch 79/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0585
# Epoch 80/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0578
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0566
# Epoch 82/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0561
# Epoch 83/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0545
# Epoch 84/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0585
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0587
# Epoch 86/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0641
# Epoch 87/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0526
# Epoch 88/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0535
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0584
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0537
# Epoch 91/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0558
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0509
# Epoch 93/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0499
# Epoch 94/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0492
# Epoch 95/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0502
# Epoch 96/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0507
# Epoch 97/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0490
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0474
# Epoch 99/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0510
# Epoch 100/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0475
# 1/1 [==============================] - 1s 962ms/step - loss: 0.9508
# Test Loss: 0.9507559537887573
# 1/1 [==============================] - 1s 931ms/step

# %% [markdown]
# # let's build a simple RNN-based character-level text generator using a sample text. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 5s 34ms/step - loss: 2.9426
# Epoch 2/100
# 5/5 [==============================] - 0s 29ms/step - loss: 2.9059
# Epoch 3/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.8747
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.8431
# Epoch 5/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7881
# Epoch 6/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7431
# Epoch 7/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7627
# Epoch 8/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7270
# Epoch 9/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7186
# Epoch 10/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.7267
# Epoch 11/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7334
# Epoch 12/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7171
# Epoch 13/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7257
# Epoch 14/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7347
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7064
# Epoch 16/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7172
# Epoch 17/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7276
# Epoch 18/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7218
# Epoch 19/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7032
# Epoch 20/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7064
# Epoch 21/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7035
# Epoch 22/100
# 5/5 [==============================] - 0s 25ms/step - loss: 2.7042
# Epoch 23/100
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7036
# Epoch 24/100
# 5/5 [==============================] - 0s 22ms/step - loss: 2.7079
# Epoch 25/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7114
# Epoch 26/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7075
# Epoch 27/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.7203
# Epoch 28/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7004
# Epoch 29/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7076
# Epoch 30/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.7153
# Epoch 31/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7209
# Epoch 32/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7225
# Epoch 33/100
# 5/5 [==============================] - 0s 44ms/step - loss: 2.7178
# Epoch 34/100
# 5/5 [==============================] - 0s 27ms/step - loss: 2.7134
# Epoch 35/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7085
# Epoch 36/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7046
# Epoch 37/100
# 5/5 [==============================] - 0s 24ms/step - loss: 2.7005
# Epoch 38/100
# 5/5 [==============================] - 0s 26ms/step - loss: 2.7012
# Epoch 39/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7014
# Epoch 40/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7141
# Epoch 41/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7046
# Epoch 42/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7035
# Epoch 43/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7054
# Epoch 44/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6998
# Epoch 45/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6977
# Epoch 46/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7048
# Epoch 47/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7002
# Epoch 48/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6928
# Epoch 49/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6940
# Epoch 50/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.7054
# Epoch 51/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7059
# Epoch 52/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7026
# Epoch 53/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6896
# Epoch 54/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6893
# Epoch 55/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7107
# Epoch 56/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7125
# Epoch 57/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6996
# Epoch 58/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7044
# Epoch 59/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7067
# Epoch 60/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6942
# Epoch 61/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6886
# Epoch 62/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6886
# Epoch 63/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6933
# Epoch 64/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6912
# Epoch 65/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6885
# Epoch 66/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6874
# Epoch 67/100
# 5/5 [==============================] - 0s 27ms/step - loss: 2.6987
# Epoch 68/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6859
# Epoch 69/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.6844
# Epoch 70/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6817
# Epoch 71/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6842
# Epoch 72/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6831
# Epoch 73/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6851
# Epoch 74/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6940
# Epoch 75/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6930
# Epoch 76/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6897
# Epoch 77/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6814
# Epoch 78/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6908
# Epoch 79/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6935
# Epoch 80/100
# 5/5 [==============================] - 0s 27ms/step - loss: 2.6864
# Epoch 81/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.6795
# Epoch 82/100
# 5/5 [==============================] - 0s 25ms/step - loss: 2.6758
# Epoch 83/100
# 5/5 [==============================] - 0s 26ms/step - loss: 2.6853
# Epoch 84/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6862
# Epoch 85/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6708
# Epoch 86/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.6679
# Epoch 87/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6829
# Epoch 88/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6825
# Epoch 89/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6653
# Epoch 90/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6698
# Epoch 91/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6792
# Epoch 92/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6854
# Epoch 93/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6882
# Epoch 94/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6861
# Epoch 95/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6817
# Epoch 96/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6665
# Epoch 97/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6620
# Epoch 98/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6498
# Epoch 99/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6387
# Epoch 100/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6352
# Seed:
# "  a simple  "
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step

# %% [markdown]
# Here, we first convert our sample text into sequences of characters. Each sequence of characters (X) corresponds to a next character (y). The model is trained to predict y from X.
#
# After training, we take a random seed sequence and use the model to predict the next 50 characters. The output will show the initial seed and the generated text based on it.

# %% [markdown]
# # GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU  # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)),  # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 7s 42ms/step - loss: 1.1082
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9464
# Epoch 3/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8151
# Epoch 4/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.7012
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5976
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5081
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4251
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3521
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2979
# Epoch 10/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2477
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2098
# Epoch 12/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1861
# Epoch 13/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1761
# Epoch 14/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1726
# Epoch 15/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1717
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1706
# Epoch 17/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1690
# Epoch 18/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1642
# Epoch 19/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1625
# Epoch 20/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1610
# Epoch 21/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1587
# Epoch 22/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1570
# Epoch 23/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1562
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1522
# Epoch 25/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1512
# Epoch 26/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1497
# Epoch 27/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1485
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1471
# Epoch 29/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1457
# Epoch 30/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1443
# Epoch 31/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1435
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1428
# Epoch 33/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1417
# Epoch 34/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1408
# Epoch 35/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1395
# Epoch 36/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1378
# Epoch 37/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1366
# Epoch 38/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1355
# Epoch 39/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1347
# Epoch 40/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1340
# Epoch 41/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1328
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1322
# Epoch 43/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1307
# Epoch 44/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1293
# Epoch 45/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1279
# Epoch 46/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1274
# Epoch 47/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1272
# Epoch 48/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1258
# Epoch 49/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1248
# Epoch 50/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1242
# Epoch 51/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1230
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1216
# Epoch 53/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1204
# Epoch 54/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1192
# Epoch 55/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1184
# Epoch 56/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1178
# Epoch 57/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1168
# Epoch 58/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1155
# Epoch 59/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1150
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1136
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1125
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1120
# Epoch 63/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1109
# Epoch 64/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1090
# Epoch 65/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1089
# Epoch 66/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1078
# Epoch 67/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1072
# Epoch 68/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1059
# Epoch 69/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1047
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1037
# Epoch 71/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1027
# Epoch 72/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1026
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1014
# Epoch 74/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1002
# Epoch 75/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0992
# Epoch 76/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0997
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0990
# Epoch 78/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0969
# Epoch 79/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0950
# Epoch 80/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0945
# Epoch 81/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0935
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0926
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0914
# Epoch 84/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0907
# Epoch 85/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0905
# Epoch 86/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0892
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0880
# Epoch 88/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0869
# Epoch 89/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0863
# Epoch 90/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0851
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0835
# Epoch 92/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0852
# Epoch 93/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0886
# Epoch 94/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0819
# Epoch 95/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0813
# Epoch 96/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0836
# Epoch 97/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0819
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0775
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0767
# Epoch 100/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0768
# 1/1 [==============================] - 1s 1s/step - loss: 0.7520
# Test Loss: 0.7520122528076172
# 1/1 [==============================] - 1s 849ms/step

# %% [markdown]
# # GRU on Text

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Import GRU instead of LSTM

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text)))  # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars))  # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model using GRU
model = Sequential([
    GRU(128, input_shape=(X.shape[1], X.shape[2])),  # Change LSTM to GRU here
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50):  # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 14s 41ms/step - loss: 2.9497
# Epoch 2/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.9156
# Epoch 3/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.8891
# Epoch 4/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.8627
# Epoch 5/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.8341
# Epoch 6/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7962
# Epoch 7/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7665
# Epoch 8/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7514
# Epoch 9/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7447
# Epoch 10/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7388
# Epoch 11/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7340
# Epoch 12/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7372
# Epoch 13/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7329
# Epoch 14/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7257
# Epoch 15/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7281
# Epoch 16/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7256
# Epoch 17/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7174
# Epoch 18/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7099
# Epoch 19/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7142
# Epoch 20/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7070
# Epoch 21/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6996
# Epoch 22/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6977
# Epoch 23/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7027
# Epoch 24/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7057
# Epoch 25/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7035
# Epoch 26/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6932
# Epoch 27/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6890
# Epoch 28/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.6846
# Epoch 29/100
# 5/5 [==============================] - 0s 23ms/step - loss: 2.6879
# Epoch 30/100
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6941
# Epoch 31/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7068
# Epoch 32/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7226
# Epoch 33/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7021
# Epoch 34/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6830
# Epoch 35/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6814
# Epoch 36/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6815
# Epoch 37/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6794
# Epoch 38/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6760
# Epoch 39/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6758
# Epoch 40/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6758
# Epoch 41/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6742
# Epoch 42/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6711
# Epoch 43/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6699
# Epoch 44/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6636
# Epoch 45/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6666
# Epoch 46/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6584
# Epoch 47/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6635
# Epoch 48/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6619
# Epoch 49/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6567
# Epoch 50/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6517
# Epoch 51/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6540
# Epoch 52/100
# 5/5 [==============================] - 0s 25ms/step - loss: 2.6560
# Epoch 53/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6540
# Epoch 54/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6489
# Epoch 55/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6484
# Epoch 56/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6440
# Epoch 57/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6425
# Epoch 58/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6358
# Epoch 59/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6240
# Epoch 60/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6210
# Epoch 61/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6096
# Epoch 62/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6155
# Epoch 63/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6145
# Epoch 64/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6082
# Epoch 65/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.5904
# Epoch 66/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.5637
# Epoch 67/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.5481
# Epoch 68/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.5446
# Epoch 69/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.5623
# Epoch 70/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.5219
# Epoch 71/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.5022
# Epoch 72/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.5017
# Epoch 73/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.4960
# Epoch 74/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.4650
# Epoch 75/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.4437
# Epoch 76/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.4020
# Epoch 77/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.4016
# Epoch 78/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.3820
# Epoch 79/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.3834
# Epoch 80/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.3734
# Epoch 81/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.3606
# Epoch 82/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.2888
# Epoch 83/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.2568
# Epoch 84/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.2315
# Epoch 85/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1937
# Epoch 86/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.1912
# Epoch 87/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1616
# Epoch 88/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.1225
# Epoch 89/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.1830
# Epoch 90/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1002
# Epoch 91/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1294
# Epoch 92/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.0376
# Epoch 93/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.0012
# Epoch 94/100
# 5/5 [==============================] - 0s 11ms/step - loss: 1.9787
# Epoch 95/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9355
# Epoch 96/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.8867
# Epoch 97/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.8802
# Epoch 98/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.8440
# Epoch 99/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9495
# Epoch 100/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7616
# Seed:
# " s a simple "
#   thrple  thrple  thrple  thrple  thrple  thrple
